# %% [markdown]
# # Visualization - Meshes

# %%
import sys,os

RES_PATH = '../../../../resources' 

if not os.path.exists(RES_PATH):
    print( 'cannot find \resources\, please update RES_PATH')
    exit(1)
else:
    pass


import pyglet
pyglet.options['shadow_window'] = False

import pyrender
import numpy as np
import trimesh

import matplotlib
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Create a Mesh render object from Trimesh.Mesh

# %%
mesh_fp = os.path.join(RES_PATH,'torus.obj')
assert os.path.exists(mesh_fp), 'cannot found:'+mesh_fp 

tm = trimesh.load_mesh(mesh_fp) 

print('tm.type=',type(tm))

mesh_rd = pyrender.Mesh.from_trimesh(tm)

print('mesh.type=',type(mesh_rd))
# Out:
# tm.type= <class 'trimesh.base.Trimesh'>
# mesh.type= <class 'pyrender.mesh.Mesh'>

# %% [markdown]
# ## Add the mesh to scene and display

# %%
def scene_factory(render_list, return_nodes=False):
    
    scene = pyrender.Scene(ambient_light=0.5*np.array([1.0, 1.0, 1.0, 1.0]))
    
    nd_list=[]
    for m in render_list:
        nd=scene.add(m)
        nd_list.append(nd)
    
    if return_nodes:
        return scene, nd_list
    else:
        return scene

# %%
def show_mesh_gui(rdobj):
    scene = scene_factory([rdobj])
    v=pyrender.Viewer(scene, use_raymond_lighting=True)
    del v
    
show_mesh_gui(mesh_rd)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 6
#       3     v=pyrender.Viewer(scene, use_raymond_lighting=True)
#       4     del v
# ----> 6 show_mesh_gui(mesh_rd)
#
# Cell In[18], line 3, in show_mesh_gui(rdobj)
#       1 def show_mesh_gui(rdobj):
#       2     scene = scene_factory([rdobj])
# ----> 3     v=pyrender.Viewer(scene, use_raymond_lighting=True)
#       4     del v
#
# File ~/miniconda3/envs/geo_tutorials/lib/python3.9/site-packages/pyrender/viewer.py:300, in Viewer.__init__(self, scene, viewport_size, render_flags, viewer_flags, registered_keys, run_in_thread, **kwargs)
#     298 # Set defaults as needed
#     299 if zfar is None:
# --> 300     zfar = max(scene.scale * 10.0, DEFAULT_Z_FAR)
#     301 if znear is None or znear == 0:
#     302     if scene.scale == 0:
#
# File ~/miniconda3/envs/geo_tutorials/lib/python3.9/site-packages/pyrender/scene.py:254, in Scene.scale(self)
#     250 @property
#     251 def scale(self):
#     252     """(3,) float : The length of the diagonal of the scene's AABB.
#     253     """
# --> 254     return np.linalg.norm(self.extents)
#
# File ~/miniconda3/envs/geo_tutorials/lib/python3.9/site-packages/pyrender/scene.py:248, in Scene.extents(self)
#     244 @property
#     245 def extents(self):
#     246     """(3,) float : The lengths of the axes of the scene's AABB.
#     247     """
# --> 248     return np.diff(self.bounds, axis=0).reshape(-1)
#
# File ~/miniconda3/envs/geo_tutorials/lib/python3.9/site-packages/pyrender/scene.py:226, in Scene.bounds(self)
#     224 mesh = mesh_node.mesh
#     225 pose = self.get_pose(mesh_node)
# --> 226 corners_local = trimesh.bounds.corners(mesh.bounds)
#     227 corners_world = pose[:3,:3].dot(corners_local.T).T + pose[:3,3]
#     228 corners.append(corners_world)
#
# File ~/miniconda3/envs/geo_tutorials/lib/python3.9/site-packages/pyrender/mesh.py:87, in Mesh.bounds(self)
#      84 """(2,3) float : The axis-aligned bounds of the mesh.
#      85 """
#      86 if self._bounds is None:
# ---> 87     bounds = np.array([[np.infty, np.infty, np.infty],
#      88                        [-np.infty, -np.infty, -np.infty]])
#      89     for p in self.primitives:
#      90         bounds[0] = np.minimum(bounds[0], p.bounds[0])
#
# File ~/miniconda3/envs/geo_tutorials/lib/python3.9/site-packages/numpy/__init__.py:397, in __getattr__(attr)
#     394     raise AttributeError(__former_attrs__[attr])
#     396 if attr in __expired_attributes__:
# --> 397     raise AttributeError(
#     398         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     399         f"{__expired_attributes__[attr]}"
#     400     )
#     402 if attr == "chararray":
#     403     warnings.warn(
#     404         "`np.chararray` is deprecated and will be removed from "
#     405         "the main namespace in the future. Use an array with a string "
#     406         "or bytes dtype instead.", DeprecationWarning, stacklevel=2)
#
# AttributeError: `np.infty` was removed in the NumPy 2.0 release. Use `np.inf` instead.

# %%
def show_offline_render(mesh_rd):   
    camera = pyrender.PerspectiveCamera(yfov=np.pi / 3.0, aspectRatio=1.0) 
    camera_pose = np.eye(4)
    camera_pose[2,2]=-1
    camera_pose[:3,3] = np.array((0.0, 0.0,-10))
    
    scene = scene_factory([mesh_rd])
    scene.add(camera, pose=camera_pose)
    
    r = pyrender.OffscreenRenderer(viewport_width=400, viewport_height=400)
    color, depth = r.render(scene)
    r.delete()

    plt.figure(dpi=100)
    plt.imshow(color) 
    plt.axis('off')

show_offline_render(mesh_rd)

# %% [markdown]
# ## Change mesh's vertice colors

# %%
mesh_fp = os.path.join(RES_PATH,'torus.obj')
assert os.path.exists(mesh_fp), 'cannot found:'+mesh_fp 
tm = trimesh.load_mesh(mesh_fp) 

# set flat color
#tm.visual.vertex_colors=(0.0,0.5,0.5)

# set random color
num = tm.vertices.shape[0]
tm.visual.vertex_colors=np.random.rand(num,3)

# convert to pyredner object
mesh_rd = pyrender.Mesh.from_trimesh(tm)

# %%
show_mesh_gui(mesh_rd)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 show_mesh_gui(mesh_rd)
#
# Cell In[18], line 3, in show_mesh_gui(rdobj)
#       1 def show_mesh_gui(rdobj):
#       2     scene = scene_factory([rdobj])
# ----> 3     v=pyrender.Viewer(scene, use_raymond_lighting=True)
#       4     del v
#
# File ~/miniconda3/envs/geo_tutorials/lib/python3.9/site-packages/pyrender/viewer.py:300, in Viewer.__init__(self, scene, viewport_size, render_flags, viewer_flags, registered_keys, run_in_thread, **kwargs)
#     298 # Set defaults as needed
#     299 if zfar is None:
# --> 300     zfar = max(scene.scale * 10.0, DEFAULT_Z_FAR)
#     301 if znear is None or znear == 0:
#     302     if scene.scale == 0:
#
# File ~/miniconda3/envs/geo_tutorials/lib/python3.9/site-packages/pyrender/scene.py:254, in Scene.scale(self)
#     250 @property
#     251 def scale(self):
#     252     """(3,) float : The length of the diagonal of the scene's AABB.
#     253     """
# --> 254     return np.linalg.norm(self.extents)
#
# File ~/miniconda3/envs/geo_tutorials/lib/python3.9/site-packages/pyrender/scene.py:248, in Scene.extents(self)
#     244 @property
#     245 def extents(self):
#     246     """(3,) float : The lengths of the axes of the scene's AABB.
#     247     """
# --> 248     return np.diff(self.bounds, axis=0).reshape(-1)
#
# File ~/miniconda3/envs/geo_tutorials/lib/python3.9/site-packages/pyrender/scene.py:226, in Scene.bounds(self)
#     224 mesh = mesh_node.mesh
#     225 pose = self.get_pose(mesh_node)
# --> 226 corners_local = trimesh.bounds.corners(mesh.bounds)
#     227 corners_world = pose[:3,:3].dot(corners_local.T).T + pose[:3,3]
#     228 corners.append(corners_world)
#
# File ~/miniconda3/envs/geo_tutorials/lib/python3.9/site-packages/pyrender/mesh.py:87, in Mesh.bounds(self)
#      84 """(2,3) float : The axis-aligned bounds of the mesh.
#      85 """
#      86 if self._bounds is None:
# ---> 87     bounds = np.array([[np.infty, np.infty, np.infty],
#      88                        [-np.infty, -np.infty, -np.infty]])
#      89     for p in self.primitives:
#      90         bounds[0] = np.minimum(bounds[0], p.bounds[0])
#
# File ~/miniconda3/envs/geo_tutorials/lib/python3.9/site-packages/numpy/__init__.py:397, in __getattr__(attr)
#     394     raise AttributeError(__former_attrs__[attr])
#     396 if attr in __expired_attributes__:
# --> 397     raise AttributeError(
#     398         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     399         f"{__expired_attributes__[attr]}"
#     400     )
#     402 if attr == "chararray":
#     403     warnings.warn(
#     404         "`np.chararray` is deprecated and will be removed from "
#     405         "the main namespace in the future. Use an array with a string "
#     406         "or bytes dtype instead.", DeprecationWarning, stacklevel=2)
#
# AttributeError: `np.infty` was removed in the NumPy 2.0 release. Use `np.inf` instead.

# %% [markdown]
# ## Display
# ![](../imgs/mesh_viewer.JPG)

# %%
def run_offline(rdobj):   
    camera = pyrender.PerspectiveCamera(yfov=np.pi / 3.0, aspectRatio=1.0) 
    camera_pose = np.eye(4)
    camera_pose[2,2]=-1
    camera_pose[:3,3] = np.array((0.0, 0.0,-10))
    
    scene = scene_factory(rdobj)
    scene.add(camera, pose=camera_pose)
    
    r = pyrender.OffscreenRenderer(viewport_width=400, viewport_height=400)
    color, depth = r.render(scene)
    r.delete()

    plt.figure(dpi=100)
    plt.imshow(color) 
    plt.axis('off')

show_offline_render(mesh_rd)
